# %%
import random
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
import requests
from bs4 import BeautifulSoup
import threading
import json
import pprint

#driver = webdriver.Chrome("./chromedriver.exe")
#driver.get("https://www.critica.com.pa/mundo")
gizmodo = {} #DICCIONARIO
gizmodo['Articles'] = []
europa_press = {}
europa_press['Articles'] = []

URL = 'https://es.gizmodo.com/c/tecnologia'
URL_MUNDO = 'https://www.europapress.es/internacional/'
        
def content_page(link):
    link_cont = requests.get(link)
    soup = BeautifulSoup(link_cont.text, 'html.parser')
    container = soup.find_all('p',{'class':'sc-77igqf-0 dQFbxq'})
    parraf = []
    for parrafo in container:
        parrafo
        parraf.append(parrafo.getText())
    return(parraf)
    #return parraf

class Scrapy:
    def __ini__(self,title,author,content,date,urlLink,cont_link,img):
        self.title = title
        self.author = author
        self.content = content
        self.date = date
        self.urlLink = urlLink
        self.cont_link = cont_link
        self.img = img
        
    def __str__(self):
        return str(self.__class__) + ": " + str(self.__dict__)

    


            
def webSite():
    re = requests.get(URL)
    if re.status_code == 200:
        soup = BeautifulSoup(re.text, 'html.parser')

        if soup is not None:
            articles = soup.find_all('article',{'class':'cw4lnv-0 iTueKC js_post_item'})
            #redires = soup.find_all
            cant_redir = len(soup.find_all('a')) #REDIRECCIONES
            #noticias['Articles'].append({'Redir':cant_redir})
            for article in articles:
                #IMPRIME EL TITULO DEL ARTICULO
                titulo = article.find('h2', {'class':'sc-759qgu-0 iSjOfj cw4lnv-6 fGbMFF'}).getText()
                #IMPRIME EL AUTOR DEL ARTICULO
                autor = article.find('div',{'class':'sc-1mep9y1-0 sc-1ixdk2y-0 fCQpxO sc-1rye1-3 hwANEt'}).text
                #IMPRIME EL LINK DEL ARTICULO
                link = article.find('a',{'class':'sc-1out364-0 hMndXN js_link'}).get('href')
                #IMPRIME EL CONTENIDO DEL ARTICULO
                article_content = content_page(link)
                #IMPRIME LA FECHA DEL ARTICULO
                fecha = article.find('div',{'class':'sc-3nbvzd-1 kpXIm'}).getText()
                #IMPRIME EN LINK DE LA IMAGEN DEL ARTICULO
                imagen = article.find('img',{'data-format':'jpg'}).get('srcset')
                gizmodo['Articles'].append({
                    'Redir':cant_redir,
                    'Title':titulo,
                    'Author':autor,
                    'Link':link,
                    'Content':article_content,
                    'Date':fecha,
                    'Img':imagen
                })

            print(gizmodo)
            with open('gizmodo.json','w') as f:
                json.dump(gizmodo, f, indent=4)

                
                
def elMundo():
    re = requests.get(URL_MUNDO)
    aja = re.status_code
    print(aja)
    if re.status_code == 200:
        soup = BeautifulSoup(re.text, 'html.parser')

        if soup is not None:
            mundo_articles = soup.find_all('article',{'class':'articulo-portada'})
            
            #redires = soup.find_all
            mundo_redir = len(soup.find_all('a')) #REDIRECCIONES
            #print(mundo_redir)
            #noticias['Articles'].append({'Redir':cant_redir})
            for article in mundo_articles:
                mundo_title = article.find('h2',{'class':'articulo-titulo'}).getText()
                #print(mundo_title)
                mundo_fecha = article.find('time',{'class':'hora_hace'}).getText()
                #print(mundo_fecha)
                mundo_link = article.find('a').get('href')
                #print(mundo_link)
                
                link_req = requests.get(mundo_link)
                soup = BeautifulSoup(link_req.text, 'html.parser')
                mundo_container = soup.find_all('div',{'id':'NoticiaPrincipal'})
                for mundo_art in mundo_container:
                    #mundo_autor = mundo_art.find('span',{'class':'fotoPie'})
                    mundo_autor = mundo_art.find('div',{'class':'captionv2'}).getText()
                    mundo_autor = mundo_autor.split(" - ")
                    #print(f'Author: {mundo_autor[1]}')
                    mundo_imagen = mundo_art.find('img',{'id':'fotoPrincipalNoticia'}).get('src')
                    #print(f'Imagen: {mundo_imagen}')
                    mundo_parrafos = soup.find_all('div',{'id':'CuerpoNoticiav2'})
                    mundo_parraf = []
                    for parra in mundo_parrafos:
                        mundo_parraf.append(parra.getText())
                        #print(f'Contenido: {mundo_parraf}')
                
                europa_press['Articles'].append({
                    'Redir':mundo_redir,
                    'Title':mundo_title,
                    'Author':mundo_autor,
                    'Link':mundo_link,
                    'Content':mundo_parraf,
                    'Date':mundo_fecha,
                    'Img':mundo_imagen
                })
                
                print(europa_press)
                
                with open('europapress.json','w') as f:
                    json.dump(europa_press, f, indent=4)


if __name__ == '__main__':
    webSite()
    elMundo()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-c9f2453307cb> in <module>
#     144
#     145 if __name__ == '__main__':
# --> 146     webSite()
#     147     elMundo()
#     148
#
# <ipython-input-2-c9f2453307cb> in webSite()
#      72                 fecha = article.find('div',{'class':'sc-3nbvzd-1 kpXIm'}).getText()
#      73                 #IMPRIME EN LINK DE LA IMAGEN DEL ARTICULO
# ---> 74                 imagen = article.find('img',{'data-format':'jpg'}).get('srcset')
#      75                 gizmodo['Articles'].append({
#      76                     'Redir':cant_redir,
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
import random
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
import requests
from bs4 import BeautifulSoup
import threading
import json
import pprint

noticias = {} #DICCIONARIO
noticias['Articles'] = []

URL_MUNDO = 'https://www.europapress.es/internacional/'


def elMundo():
    re = requests.get(URL_MUNDO)
    aja = re.status_code
    print(aja)
    if re.status_code == 200:
        soup = BeautifulSoup(re.text, 'html.parser')

        if soup is not None:
            mundo_articles = soup.find_all('article',{'class':'articulo-portada'})
            
            #redires = soup.find_all
            mundo_redir = len(soup.find_all('a')) #REDIRECCIONES
            print(mundo_redir)
            #noticias['Articles'].append({'Redir':cant_redir})
            for article in mundo_articles:
                mundo_title = article.find('h2',{'class':'articulo-titulo'}).getText()
                print(mundo_title)
                mundo_fecha = article.find('time',{'class':'hora_hace'}).getText()
                #print(mundo_fecha)
                mundo_link = article.find('a').get('href')
                print(mundo_link)
                
                link_req = requests.get(mundo_link)
                soup = BeautifulSoup(link_req.text, 'html.parser')
                mundo_container = soup.find_all('div',{'id':'NoticiaPrincipal'})
                for mundo_art in mundo_container:
                    #mundo_autor = mundo_art.find('span',{'class':'fotoPie'})
                    mundo_autor = mundo_art.find('div',{'class':'captionv2'})
                    mundo_autor = mundo_autor.split(" - ")
                    print(f'Author: {mundo_autor[1]}')
                    mundo_imagen = mundo_art.find('img',{'id':'fotoPrincipalNoticia'}).get('src')
                    print(f'Imagen: {mundo_imagen}')
                    mundo_parrafos = soup.find_all('div',{'id':'CuerpoNoticiav2'})
                    mundo_parraf = []
                    for parra in mundo_parrafos:
                        mundo_parraf.append(parra.getText())
                        print(f'Contenido: {mundo_parraf}')
'''            
            noticias['Articles'].append({
                'Redir':mundo_redir,
                'Title':mundo_title,
                'Author':mundo_autor,
                'Link':mundo_link,
                'Content':mundo_parraf,
                'Date':mundo_fecha,
                'Img':mundo_imagen
            })

            print(noticias)

            with open('file.json','w') as f:
                json.dump(noticias, f, indent=4)
'''
if __name__ == '__main__':
    elMundo()

# %%
#TERCERA WEB - EN INGLES
import random
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
import requests
from bs4 import BeautifulSoup
import threading
import json
import pprint

vanguardia = {} #DICCIONARIO
vanguardia['Articles'] = []

URL_ALMIN = 'https://www.lavanguardia.com/alminuto'


def laVanguardia():
    re = requests.get(URL_ALMIN)
    aja = re.status_code
    print(aja)
    if re.status_code == 200:
        soup = BeautifulSoup(re.text, 'html.parser')

        if soup is not None:
            van_articles = soup.find_all('li',{'class':'results-item'})
            
            #redires = soup.find_all
            van_redir = len(soup.find_all('a')) #REDIRECCIONES
            print(van_redir)
            #noticias['Articles'].append({'Redir':cant_redir})
            for van_article in van_articles:
                van_title = van_article.find('h1',{'class':'story-header-title'}).getText()
                print(van_title)
                van_link = van_article.find('a',{'class':'story-header-title-link'}).get('href')
                print(van_link)
                #TOMA EL LINK DEL POST EN MINIATURA PARA HACER UN NUEVO REQUEST, PERO ESTA VEZ DESDE DENTRO DEL POST
                link_vanreq = requests.get(van_link)
                soup = BeautifulSoup(link_vanreq.text, 'html.parser')
                van_container = soup.find_all('div',{'class':'detail__main'})
                for van_art in van_container:
                    #CAPTURA EL AUTOR SI ESTA DISPONIBLE LA ETIQUETA
                    if(van_art.find('figcaption',{'class':'img-figcaption'})):
                        van_autor = van_art.find('figcaption',{'class':'img-figcaption'}).text
                        print(f'Author: {van_autor}')
                    else:
                        van_autor = 'Sin autor'
                        print(f'Author: {van_autor}')
                    #CAPTURA LA FECHA
                    van_fecha = van_art.find('time',{'class':'d-signature__time'}).text
                    print(f'Fecha: {van_fecha}')
                    #sI EXISTE LA ETIQUETA DE IMAGEN LA CAPTURA
                    if(van_art.find('img',{'class':'img-responsive'})):
                        van_imagen = van_art.find('img',{'class':'img-responsive'}).get('src')
                        print(f'Imagen: {van_imagen}')
                    else:
                        van_imagen = 'Imagen no disponible'
                        print(f'Imagen: {van_imagen}')
                    #BUSCA EL CONTENEDOR PADRE DE LOS PARRAFOS Y CAPTURA CADA PARRAFO
                    van_parrafos = soup.find_all('div',{'itemprop':'articleBody'})
                    van_parraf = []
                    for van_parra in van_parrafos:
                        van_parraf.append(van_parra.getText())
                        print(f'Contenido: {van_parraf}')
'''
                    vanguardia['Articles'].append({
                        'Redir':van_redir,
                        'Title':van_title,
                        'Author':van_autor,
                        'Link':van_link,
                        'Content':van_parraf,
                        'Date':van_fecha,
                        'Img':van_imagen
                    })

                    print(vanguardia)

            #with open('vanguardia.json','w') as f:
                #json.dump(vanguardia, f, indent=4)
'''
if __name__ == '__main__':
    laVanguardia()
# Out:
# 200
# 228
#
# Gwyneth Paltrow se vuelca en su imperio comercial y en su intensa vida familiar
#
# https://www.lavanguardia.com/gente/20200623/481924190342/gwyneth-paltrow-vida-empresa-actriz.html
# Author: Gwyneth Paltrow, en una imagen reciente (VEEREN / BESTIMAGE / GTRES)
# Fecha:
# 		23/06/2020 02:21
# Imagen: https://www.lavanguardia.com/r/GODO/LV/p7/WebSite/2020/06/23/Recortada/img_smauri_20200622-103953_imagenes_lv_gtres_dl_u451400_027-kO8C-J1SW9ZQJGZAHBW9Y-992x558@LaVanguardia-Web.jpg
# Contenido: ['\nA los 47 años, con un feliz segundo matrimonio, dos hijos adolescentes y un verdadero imperio comercial que le ha ayudado a amasar una fortuna personal estimada en 125 millones de dólares, Gwyneth Paltrow no suele dedicarle mucho tiempo a su carrera como actriz. De hecho, son pocas las películas en las que ha trabajado desde que participó en Contagio con un papel de reparto, como la paciente cero que da inicio a la pandemia con el que este filme del 2011 presagió lo que ocurre actualmente con el coronavirus (aunque, claro, con una espectacularidad cinematográfica que afortunadamente está lejos de lo que nos ha tocado vivir).\n\n\n\n\n\nAun así, de vez en cuando, deja por un tiempo su intensa vida familiar y sus negocios para regresar a los platós, y así fue como conoció en el 2010 a quien hoy es su esposo, el guionista y productor Brad Falchuk, que la contrató para que se sumara a la segunda temporada de Glee \n. Según explicó Gwyneth en una entrevista reciente, enamorarse “fue una sorpresa maravillosa que yo no me esperaba, pero tuve muchísima suerte. Estoy muy agradecida de que haya pasado, porque además cuando te ocurre cuando ya eres un poco mayor, le das un valor y una importancia que no le ves cuando estás en tus 20, porque no conoces la diferencia”.\n\n\nGwyneth reconoce que aprender a ser una empresaria no le ha sido fácil y que es un proceso que nunca termina\n\n\nFalchuk fue también quien el año pasado la invitó a incorporarse al elenco de The Politician , la serie de Netflix que creó junto al hoy todopoderoso Ryan Murphy y con quien ha trabajado codo a codo desde sus inicios en cada una de sus series. Allí, Gwyneth tiene un papel de reparto con suficientes escenas como para brillar cada vez que aparece, pero también es razonablemente breve como para no interferir con sus otros proyectos, como por ejemplo The Goop Lab , otra serie de Netflix en la que aparece como ella misma y que ha sido el último eslabón en el imperio dedicado a la salud y al bienestar que empezó con un boletín informativo que la actriz enviaba por correo electrónico allá por el 2008. Luego lo transformó en una página web, a la que después sumó un servicio de ventas de productos por internet, una revista y un podcast, y que hoy está valorado en unos 220 millones de euros. “Siento que he creado un gran impacto en el mundo del bienestar”, dice orgullosa Paltrow, y agrega: “Llevo casi 12 años en este negocio y creo que hemos sido pioneros en darle permiso a las mujeres para hacerse preguntas sobre su salud, pero no solo sobre nutrición sino también sobre relaciones personales y laborales. Logramos que muchos nuevos conceptos se vuelvan parte de la cultura popular, algo que al día de hoy me sigue impresionando”.\n\n\n\n\n\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.registerLazyLoad\');\n\t\t \t})\n\t \t\t\n\n\t\t\t\t\t\t\tGwyneth Paltrow tuvo dos hijos con Chris Martin, líder de la banda Coldplay\n\t\t\t\t\t\t\t\t\t\t(instagram)\n\t\t\t\t\t\t\n\n\n\n\nGwyneth reconoce que aprender a ser una empresaria no le ha sido fácil y que es un proceso que nunca termina: “Lamentablemente aprendí mucho cometiendo errores. Sigo aprendiendo todos los días, me paso el tiempo haciendo preguntas y busco mejorar mis conocimientos, y a la vez, impulso a otras mujeres para que hagan lo mismo”, dice. Ella misma es la que aclara que si bien su negocio es su principal ocupación, nunca dirá que se ha retirado de la actuación: “Si lo hiciera, se olvidarían rápidamente de mi. Pero aunque nunca voy a decir que no volveré a actuar, tengo claro que hasta donde puedo imaginar mi futuro voy a estar concentrada en mi compañía, pero si me llaman para hacer una tercera temporada de The Politician’ allí estaré, no tengo ninguna duda”.\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.regi ...
#
# Prórroga automática para los abonos dejados a medias
#
# https://www.lavanguardia.com/local/barcelona/20200623/481924182216/abonos-tren-metro-transporte-prorroga-atm.html
# Author: Una pasajera rumbo a la playa desde la estación de Sants (Toni Albir / EFE)
# Fecha:
# 		23/06/2020 02:16
# Imagen: https://www.lavanguardia.com/r/GODO/LV/p7/WebSite/2020/06/23/Recortada/20200620-637282624818391955_20200620151500-k3HI-CJSECIPTG24ENFFU-992x558@LaVanguardia-Web.jpg
# Contenido: ['\nLos abonos de transporte dejados a medias por el confinamiento son uno de esos elementos que nos recuerdan como la vida se paró de golpe de un día para otro. Los viajeros que se mueven con la T-casual (la antigua T-10) han podido retomar su uso como si no hubiera pasado nada en todas estas semanas, pero aquellos que utilizan la nueva T-Usual u otros abonos mensuales o trimestrales como la T-Jove han visto como expiraba la caducidad sin haberles podido sacar provecho.\nLa Autoritat del Transport Metropolità (ATM) insistió desde el primer día en que se guardasen las tarjetas y serían convenientemente compensadas cuando acabase el estado de alarma. Llegados a este punto, el sistema de compensación se activará a partir del próximo miércoles 1 de julio. Y será de una extrema facilidad para los viajeros, con una prórroga automática al validarlas, según el procedimiento al que ha tenido acceso La Vanguardia .\n\n\n\n\n\n\n\nLos billetes caducados se renovarán al pasarlos por las máquinas validadoras de acceso al tren, metro o bus\n\n\nDe esta manera, todas las personas que estaban utilizando un título mensual y dejaron de hacerlo antes del 14 de marzo (el día que se declaró el estado de alarma), simplemente tendrán que pasar la tarjeta por las máquinas validadoras y automáticamente se les ampliará la caducidad por un período de días equivalentes al que le quedaba de vida útil. El sistema está preparado para hacer efectiva la prórroga en cualquiera de las máquinas en los accesos a los operadores de transporte del área de Barcelona (TMB, Rodalies, FGC, Tram y autobuses metropolitanos).\nUn poco más complejo será para aquellos que utilizaron las tarjetas después del 14 de marzo. En este caso deberán hacer una solicitud a través de una página web que se creará expresamente para ello, aportando la información requerida de manera telemática. En caso de ser aceptada la reclamación, el usuario podrá recoger una nueva tarjeta con el periodo de validez que corresponda en las oficinas de atención al cliente de los operadores cuando reabran sus puertas.\nEn un primer momento estaba previsto hacer en dependencias como los puntos TMB todo el trámite de compensación, pero finalmente se ha optado por la vía telemática para evitar posibles colas y aglomeraciones innecesarias en el momento actual.\n\n\n\n\n\nLa compensación de los abonos caducados abarca un periodo en el que estaba previsto desplegar la T-Mobilitat, la tarjeta sin contacto y personal que permitiría hacer estas devoluciones de una manera mucho más automatizada y rápida. El mes de abril se vio superado por las circunstancias globales y ahora se trabaja en un nuevo calendario de despliegue que es toda una incógnita.\n\n\n\n\n\n']
#
# El TSJC resuelve derribar el bloque Venus de la Mina
#
# https://www.lavanguardia.com/local/barcelona/20200623/481924183097/bloque-venus-la-mina-tsjc-derribo.html
# Author: El TSJC considera inhumana la vida en el edificio Venus (Javier Torres)
# Fecha:
# 		23/06/2020 02:14
# Imagen: https://www.lavanguardia.com/r/GODO/LV/p7/WebSite/2020/06/23/Recortada/img_jtorres_20191105-183905_imagenes_lv_propias_jtorres_venus-801_4_7_1440639964-kIOH-699G65HAJNA286JR-992x558@LaVanguardia-Web.jpg
# Contenido: ['\nLa primera batalla judicial para impulsar el proyecto de expropiación del edificio Venus en el barrio de la Mina de Sant Adrià de Besòs, su posterior demolición y el realojo de los residentes afectados, se ha saldado a favor de los vecinos. El Tribunal Superior de Justícia de Catalunya (TSJC) ha dictaminado que el Consorcio del Barrio de la Mina, que integran los ayuntamientos de Sant Adrià y Barcelona, junto a la Generalitat y la Diputación de Barcelona, está obligado a reactivar el proyecto.\nLas más de 300 familias que viven el edificio Venus de La Mina estaban exultantes ayer al conocer que el esfuerzo para impulsar la campaña de micromecenazgo para contratar un bufete de abogados, se había visto recompensado con la decisión del TSJC, que obliga a reiniciar el proceso que las propias administraciones habían paralizado en el 2002, una vez que los vecinos habían alegado su disconformidad con la tasación de sus viejas viviendas. El Consorcio les exigía abonar una cifra, que oscilaba entre los 30.000 y los 40.000 euros, para poder acceder a una vivienda nueva. Ante la negativa de los residentes el propio consorcio optó por desestimar todas las alegaciones, lo que también provocó la paralización de todos los trámites.\n\n\n\n\n\n\n\nEl tribunal considera vulnerado el derecho de los residentes por ser obligados a vivir de forma “inhumana”\n\n\nLa sentencia que se dio a conocer ayer obliga a derivar el expediente al Jurado de Expropiaciones de Catalunya para que fije la tasación de las viviendas, una vez se haya llevado a cabo el peritaje y el precio justo en los expedientes de expropiación. El alto tribunal admite que “no puede quedar al arbitrio de las administraciones y quedar de forma indefinida a la espera de un supuesto acuerdo con los afectados”.\nCon ello el TSJC hace suyos los argumentos de los representantes legales de los vecinos , los abogados del Col·lectiu Ronda, y considera que se han vulnerado los derechos de los vecinos del edificio Venus, que, según recoge un informe del Síndic de Greuges citado por el tribunal, describe que las condiciones de vida en estas viviendas son “inhumanas”.\nA criterio del alto tribunal catalán el Consorcio ha incurrido en una “patente inactividad” que ha consistido en la omisión de cualquier actividad relacionada con la expropiación del edificio Venus y en no haber ejecutado en su momento las medidas aprobadas en el 2002 en el Plan Especial de Reordenación y Mejora del Barrio de la Mina (PERM), que contemplaban una serie de intervenciones urbanísticas para que se pudiera proceder a la regeneración de la zona y a la actuación de forma integral en “el ámbito educativo, cívico y de seguridad contra la exclusión y la marginalidad” que aún hoy estigmatizan al barrio.\n\n\n\n\n\nLa expropiación y el realojo eran unas de las principales medidas acordadas, lo que también contribuiría a “desmantelar una de las principales bolsas de precariedad social” que aún hoy perviven en el Àrea Metropolitana de Barcelona.\nDurante más de 10 años el Consorcio del Barrio de la Mina se ha limitado a desestimar las alegaciones de los vecinos y a paralizar la demolición de Venus, obligando a sus inquilinos a vivir en un inmueble que “presenta un estado de degradación tal” que no sólo constituye un escenario “insalubre y peligroso” sino que es “un auténtico atentado contra la dignidad humana” apuntan los letrados del Col·lectiu Ronda.\n\n\n\n\n\n']
#
# Lloret controla con cámaras la ocupación en dos playas
#
# https://www.lavanguardia.com/local/girona/20200623/481924169944/camaras-videovigliancia-playas-lloret-control.html
# Author: La playa Gran de Lloret estrenó ayer la sectorización (Pere Duran / NORD MEDIA)
# Fecha:
# 		23/06/2020 02:12
# Imagen: https://www.lavanguardia.com/r/GODO/LV/p7/WebSite/2020/06/23/Recortada/img_pduran_20200622-151512_imagenes_lv_colaboradores_pduran_messures_covid_lloret_p7-kkxD-CFV8T0SQ2HGQSY5P-992x558@LaVanguardia-Web.jpg
# Contenido: ['\nDoce cámaras de videovigilancia controlarán en tiempo real la ocupación de las dos principales playas de Lloret de Mar de modo que el visitante podrá saber en todo momento cuántas personas hay en cada sector antes de tender la toalla en la arena. Los dispositivos, que ya se han em\xadpezado a instalar, estarán dotados de un software que permitirá detectar elementos hasta 400 metros de la línea de costa y saber el porcentaje de ocupación de los arenales. Una información que se irá actualizando cada cinco minutos y que el visitante podrá consultar en la web municipal, mediante una app y en los plafones informativos que se han instalado en las principales calles del municipio.\n\n\n\n\n\nDesde ayer, las playas de Lloret y Fenals se han sectorizado en función del tipo de público que las ocupará: se ha habilitado un sector para mayores de 70 años, otro para familias con hijos y un tercero para adultos y grupos de amigos. El alcalde de Lloret de Mar, Jaume Dulsat, explicó que la división de los arenales es una “recomendación” y en ningún caso una “obligación”, de modo que no se multará a nadie que opte por bañarse en una zona que no le corresponda.\n\n\nTossa de Mar ha empezado a tomar la temperatura a los visitantes de forma voluntaria\n\n\n\nPartiendo de la orden ministerial que establece un espacio de 4 m2por persona, se estima que entre la playa Gran y la de Fenals, las dos únicas que estarán dotadas de este sistema de videovigilancia, suman un aforo máximo de 25.000 personas. El objetivo final del uso de videosensores es evitar masificaciones, que los informadores de Protección Civil y vigilantes de playa sepan en tiempo real el volumen de gente que hay en cada sector y que el turista pueda elegir con conocimiento de causa en qué zona se ubica. El director de servicios digitales y administraciones públicas de Telefónica Mediterráneo, Bruno Vilarsau, quiso dejar claro ayer que el software no graba imágenes ni almacena datos y que protege la intimidad de las personas.\n\n\n\n\n\nLas videocámaras son una de las novedades que el Ayuntamiento de Lloret de Mar dio a conocer ayer en la presentación del amplio paquete de medidas que aplicará este municipio en el primer verano de la Covid-19. En el resto de calas y playas serán los vigilantes e informadores quienes se encargarán de controlar el acceso en función del aforo máximo permitido.\nTambién Tossa de Mar inició ayer el control voluntario de la temperatura a los visitantes, que se realizará en los tres apar\xadcamientos de entrada al municipio. La alcaldesa, Imma Colom, apela a la “conciencia ciudadana” y a la ”responsabilidad” de los turistas para permitir el control termométrico, aunque reconoce que si alguien se niega no se le impedirá que visite el municipio. En caso de alguna persona tenga fiebre alta se le ofrecerá la posibilidad de contactar con un sanitario vía telefónica.\nEl Consistorio también ha creado una app que permitirá al turista saber la afluencia de público que hay en los atractivos turísticos de Tossa como la Vila Vella, el faro o en las playas. El Consistorio ha estimado la cifra máxima de 9.000 bañistas al día en su litoral. Un servicio de vigilantes velará para que los bañistas guarden las distancias de seguridad y prohibirá los deportes en grupo aunque sí permitirá jugar por parejas en las zonas más alejadas del agua.\n\n\n\n\n\n']
#
# Pere Chias: “La recuperación llegará en primavera”
#
# https://www.lavanguardia.com/local/barcelona/20200623/481924138228/pere-chias-gremi-restauracio-barcelona-entrevista.html
# Author: Pere Chias (LV)
# Fecha:
# 		23/06/2020 02:10
# Imagen: https://www.lavanguardia.com/r/GODO/LV/p7/WebSite/2020/06/23/Recortada/img_jalvarez_20200512-163414_imagenes_lv_terceros_perechias-ghb-hde-kpWB-J4ULZOD2UGZOK5P8-992x558@LaVanguardia-Web.jpeg
# Contenido: ['\nPere Chias preside el Gremi de Restauració de Barcelona en los tiempos sin duda más convulsos del sector. Está convencido de que los bares y los restaurantes volverán a ser lo que eran. Su reto es que nadie se quede por el camino.\n¿Hay una burbuja de bares?No. En la última década la ciudad gozó de una relativa buena salud económica. Desde el 2017 se dio cierta erosión, pero las cifras seguían siendo buenas. Tenemos una oferta dimensionada en base a esta Barcelona bien posicionada internacionalmente. Pero la pandemia conllevará ajustes.¿Temporales o definitivos?Está en manos del Gobierno central. La ampliación de los ERTE hasta finales de año es imprescindible. Los locales han reabierto, pero la demanda sigue en cuarentena. Solo los ERTE pueden evitar las reestructuraciones de plantilla.\n\n\n\n\n\n¿Qué más echa de menos ?El Gobierno central impuso acertadamente el cierre de la restauración, pero luego debería haber arbitrado una solución para los alquileres. Apelar a la solidaridad de los arrendadores no basta. Debe imponerse por ley la obligación de renegociar los contratos. Hay que adaptar las rentas al nuevo contexto.¿El sector recuperará la normalidad? ¿Cuándo?La temporada de verano está perdida. La recuperación no se alcanzará antes de la Semana Santa del 2021. El reto para muchos negocios será aguantar hasta entonces. Estamos viendo cómo las comunidades han empezado a codiseñar el relanzamiento de la restauración con los representantes del sector. En Catalunya hemos de darnos prisa y elaborar un plan sectorial para la nueva normalidad. Insistir en la reducción de aforo es un error.\n¿La pandemia cambiará el hábito de ir a bares y restaurantes?No. Los bares y restaurantes son puntos de encuentro. La gente tenía muchas ganas de recuperarlos. Con todas las precauciones sanitarias necesarias, los locales de restauración continuarán formando parte de nuestra cotidianidad.\n\n\n\n\n\n']
#
# Arrancan las colonias de verano con un aumento de las inscripciones
#
# https://www.lavanguardia.com/vida/20200623/481924150636/colonias-verano-casal-ninos-inscripciones-seguridad.html
# Author: Momento de comer, con distancia, en el casal de la Fundació Pere Tarrés en el colegio Sant Gregori (Àlex Garcia)
# Fecha:
# 		23/06/2020 02:08
# Imagen: https://www.lavanguardia.com/r/GODO/LV/p7/WebSite/2020/06
villa Crespo, Chacarita o Colegiales. Algunos de los restaurantes más prestigiosos han cerrado en esta cuarentena, que ya dura más de tres meses. Otros, incluyendo los de alta gastronomía, se han reinventado para ofrecer un servicio a domicilio de nivel o han buscado una solución más imaginativa, como Don Julio, considerado el mejor restaurante del país y el cuarto de la región, según la lista 50 Best Restaurants de Latinoamérica\n\n\n\n\n\n\n\n\nPalermo es el barrio más noctámbulo de Buenos Aires pero ahora se apaga por completo a medianoche\n\n\nLa esquina de Don Julio siempre estaba llena de clientes esperando turno. Ahora las persianas están bajadas pero a unos metros de la misma calle, en un local cerrado al público, una cámara acorazada por el frío guarda el tesoro de este restaurante: sus carnes maduradas. El problema de Don Julio es que se trata de una parrilla, el hábito gastronómico por excelencia de los argentinos. Y una parrilla de su nivel no podía ofrecer asados a domicilio, así que su dueño decidió volver a los orígenes del negocio y reconvertirla en carnicería de lujo.\n“Hoy lo mejor que podemos dar en este contexto es todo el trabajo que hacemos antes de cocinar, porque después de cocinado, en el empaque que va al delivery, se pierde mucho la calidad, la carne no reacciona bien al envío, y decidimos volver a lo que era el oficio de mis abuelos, que tenían una carnicería”, explica a La Vanguardia el propietario del restaurante, Pablo Rivero.\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.registerLazyLoad\');\n\t\t \t})\n\t \t\t\n\n\t\t\t\t\t\t\tRestaurante Don Julio en Buenos Aires\n\t\t\t\t\t\t\t\t\t\t(Robert Mur)\n\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n\n\nCada corte tiene un tiempo \xadespecífico de maduración, sale del frigorífico y llega a casa envasado al vacío. Esta carnicería de alto \xadstanding vende unas siete to\xadneladas al mes –sobre todo ojo de bife (lomo), entraña y tira de asado– a un precio superior al de una tienda tradicional, Rivero sigue haciendo frente a las nóminas de 120 empleados de un negocio que servía diariamente 500 cubiertos y unas 16 toneladas de carne asada al mes.\nLos argentinos llevan tres meses sin poder salir a una parrilla y no se prevé que puedan hacerlo al menos hasta septiembre. Asados se siguen haciendo en las casas, pero no con tanta gente como antes, por lo que el consumo de carne y su precio \xadestán bajando. No obstante, más de un asado clandestino ha sido detectado ya por las autoridades al \xadprovocar focos de contagio.\nNo lejos de Don Julio hay otro caso de reinvención urgente por la pandemia. El restaurante Mercado de Liniers llevaba solo dos días abierto al público cuando la cuarentena obligó a cerrar. El local era la nueva apuesta de Dante Liporace, el chef de la Casa Rosada durante el anterior gobierno de Mauricio Macri y uno de los estandartes de la alta cocina argentina. Diez días después del mazazo, iniciaron el servicio a domicilio, eligiendo diez platos de su exclusiva carta, cocinados y envasados al vacío con diez minutos menos de cocción, que el cliente debe completar en casa. “El primer día nos quedamos sin mercadería”, dice Liporace a este diario junto a los fogones de su flamante restaurante, a media mañana y mientras los cocineros no paran de preparar comida. “Este negoci ...
#
# Saba ficha como consejera a la exministra Elena Salgado
#
# https://www.lavanguardia.com/economia/20200623/481923980348/saba-empresa-elena-salgado.html
# Author: Elena Salgado (Emilia Gutiérrez/ ARCHIVO)
# Fecha:
# 		23/06/2020 01:51
# Imagen: https://www.lavanguardia.com/r/GODO/LV/p7/WebSite/2020/06
# Imagen: https://www.lavanguardia.com/r/GODO/LV/p7/WebSite/2020/06/23/Recortada/img_smoreno_20190404-184408_imagenes_lv_terceros_istock-153794211-kUdG-U481908953867e4-992x558@LaVanguardia-Web.jpg
# Contenido: ['\nLas gasolineras automáticas, conocidas también con el nombre de fantasmas, puesto que el conductor realiza tanto el repostaje, como el pago del carburante, han ganado cuota de mercado durante el último año. “Existen ya 1.033 estaciones de este tipo, lo que representa una cuota de mercado del 10% y un crecimiento del 17% en el último año”, recoge el estudio elaborado por la Asociación Nacional de Estaciones de Servicio (Aesae), con datos hasta abril de este año. En algunas comunidades autónomas, como Catalunya, la cuota ya se sitúa entorno al 20%, con un total de 288. De las que la mayoría están en Barcelona (157), seguidas por las de Tarragona (58), Girona (37) y Lleida (36). \n\n\n\n\n\n“Con la pandemia se ha incrementado el número de visitantes a nuestras estaciones por miedo a a los contagios en las tradicionales y porque han percibido que el precio de los carburantes es entorno a un 2% inferior”, señala Manuel Jiménez Perona, presidente de dicha organización.\nEste directivo explica a La Vanguardia que este sector no pidió al Gobierno el cierre de algunas de sus gasolineras “porque no existe riesgo de contagio”. Y entre sus ventajas, destaca, que “disponen de detectores de fuego en el suelo, que en cuanto se llega a 60 grados se disparan de forma automática para evitar incendios”.\n\n\n“Todas las gasolineras sin personal in situ disponen de un sistema contra incendios en el suelo”\n\n\nEntre las enseñas que más están creciendo en este negocio se encuentran enseñas como Petroprix, Ballenoil o Bon Área, entre otras.\nEn su opinión, “otro de los motivos del crecimiento es que algunas comunidades autónomas, como Castilla- La Mancha, Castilla y Léon o Madrid han eliminado las restricciones que existían para abrir este tipo de gasolineras, tras una denuncia que pusimos en Bruselas porque se limitaba mucho la posibilidad de implantar este tipo de gasolineras sin personal in situ”. A lo que añade de forma rápida: “No se trata de gasolineras desatendidas, puesto que de media generan 1,5 empleos, ya que requieren actuaciones de mantenimiento, mecánica, software, limpieza...”.\n\n\n\n\n\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.registerLazyLoad\');\n\t\t \t})\n\t \t\t\n\n\t\t\t\t\t\t\tGasolineras automáticas\n\t\t\t\t\t\t\t\t\t\t(Rosa M.ª Anechina)\n\t\t\t\t\t\t\n\n\n\n\nLa inversión para instalar una estación de servicio de ese tipo varia en función de los surtidores que se coloquen, de si se pone o no túnel de lavado... pero “la media oscila entre 500.000 y un millón de euros”, señala Jiménez.\nEl presidente de la patronal defiende que un estudio de la OCU certificó que “el precio de los carburantes es de media 10 céntimos más bajo en estas estaciones de servicio, con lo que un conductor que hace unos 20.000 kilómetros al año se puede ahorrar entre 280 y 320 euros al año”.\nEn España el negocio de la venta de carburantes está monopolizado por tres operadores verticales integrados (Repsol, Cepsa y BP). Después, hay un grupo de operadores mayoristas sin capacidad de refino, pero abanderadas por una marca. En este grupo se encuentran compañías como Disa, ERG Petróleos, Esergui, Fuel Iberia, Galp, Kuwait Petroleum España, Meroil, Noroil, Saras Energía, Shell, Total o Tomoil. Por último, hay un tercer grupo, vinculado en ocasiones a grupos de distribución, que operan de forma independiente sin contratos de exclusividad.\n\n\n\n\n\nEl negocio de las estaciones de servicio mueve unos 40.000 millones de euros al año en España, lo que supone casi un 4% del PIB español. Todo el sector notó caídas significativas los días de confinamiento duro, pero prevén que en la segunda parte del año las ventas se recuperen.\n\n\n\n\n\n']
#
# Freixenet crece un 4,6%, pero frena las inversiones
#
# https://www.lavanguardia.com/economia/20200623/481923936029/freixenet-cava-crecimiento.html
# Author: Cavas Freixent, en Sant Sadurní d’Anoia (Llibert Teixidó)
# Fecha:
# 		23/06/2020 01:46
# Imagen: https://www.lavanguardia.com/r/GODO/LV/p7/WebSite/2020/06/23/Recortada/img_lteixidor_20160520-143804_imagenes_lv_colaboradores_lteixidor_freixenet_9715_21-kmRF-U481914029089jj-992x558@LaVanguardia-Web.jpg
# Contenido: ['\nGrupo Freixenet registró un crecimiento orgánico del 4,6% en el 2019. Henkell Freixenet y Grupo Freixenet incrementaron el año pasado su facturación un 25%, hasta los 1.290 millones. El año pasado, Grupo Freixenet y Henkell Freixenet completaron su alianza internacional, que les ha permitido convertirse en el líder mundial del sector del vino espumoso con una cuota de mercado del 9,7%. \nGrupo Freixenet sigue liderando el sector del cava en 104 países. Exporta más del 80% de sus ventas, que se concentran en Alemania, el Reino Unido, Estados Unidos, Francia y Japón. La Covid-19 les ha llevado a detener las inversiones previstas. Sin embargo, han pospuesto el ERTE en Freixenet y Segura Viudas tras la reactivación de las exportaciones. Pere Ferrer, vicepresidente y consejero delegado de Grupo Freixenet, afirma que “seguimos trabajando para alinear la estrategia con Henkell Freixenet”.\n\n\n\n\n\n']
#
# Codorniu nombra a Sergio Fuster consejero delegado para globalizarse
#
# https://www.lavanguardia.com/economia/20200623/481923946251/codorniu-sergio-fuster-relanzamiento-globalizacion.html
# Author: Sergio Fuster, nuevo consejero delegado (LV)
# Fecha:
# 		23/06/2020 01:43
# Imagen: https://www.lavanguardia.com/r/GODO/LV/p7/WebSite/2020/06/23/Recortada/img_vagustina_20200622-164039_imagenes_lv_otras_fuentes_sergio_ferrer-006-kjKG-40LMYEKOE1LPTACA-992x558@LaVanguardia-Web.jpg
# Contenido: ['\nAño y medio después de cerrarse la compra de la mayoría de Raventós Codorniu por parte del fondo de capital Carlyle, la bodega ha decidido fichar a un nuevo consejero delegado para impulsar un relanzamiento, que tiene como principal objetivo convertir a las marcas del grupo en globales. El escogido es Sergio Fuster (Gandia, 1974), ingeniero in\xaddustrial y máster en dirección \xadcomercial y marketing por Esic, un directivo ligado durante más de 20 años a empresas muy internacio\xadnales y con marcas muy potentes.\nFuster, que se incorporará a la empresa el próximo 1 de septiembre, es actualmente director de marketing global de Kellog, con \xadsede en Chicago, y ha hecho su \xadcarrera en multinacionales como Danone, donde llegó a presidente de la división de yogures en Estados Unidos, United Biscuits y Procter & Gamble. Ahora,ocupará un puesto de nuevo creación, aunque Ramon Raventós Basagoiti, director general del grupo desde noviembre del 2018, desarrollaba hasta ahora funciones equivalentes. Este directivo que asumió su cargo tras vender Gleva Cellars –elaborador de Parxet, Mont-Ferrant, Titiana, Tionio, Basagoi
probarán enseguida hasta dónde está dispuesto a llegar Eroski tanto en lo relativo al precio como en lo relativo a las múltiples condiciones de partida a los inversores.\nNo hay tiempo que perder, porque la pérdida de valor de la cadena es evidente. Caprabo facturó 790 millones en el pasado ejercicio que concluyó el pasado 31 de enero. “La marca está muy deteriorada y las ventas son casi una tercera parte de lo que llegaron a ser en el 2007, con 300 tiendas de formatos diferentes, algunas muy buenas y otras bastante malas”, apuntan fuentes financieras. “Además –añade alguien que conoce los entresijos de la operación–, Eroski busca que el futuro adquiriente no compita con su cadena para no perder volumen de compra e intentar mantener el poder de negociación con los proveedores”. Otras fuentes aseguran que la cooperativa vasca aspira a reservarse una opción de recompra. Fuentes de Eroski dijeron ayer que “Caprabo es estratégico y que no está en venta y el mandato a PwC es para dar entrada a un socio financiero”.\n\n\n\n\n\nPero eso ya se verá. Como suele ocurrir en las ventas forzadas, la operación la definirán, en última instancia, la banca y quienes acaben presentando una oferta formal. Eroski tiene un poder de negociación limitado. El calendario, ya alterado por la irrupción de la pandemia, no será exigente con los tiempos y todo apunta a que si la operación tiene éxito se cerrará después del verano en el mejor de los casos.\n\n\n\n\n\n']
#
# Kareem Abdul-Jabbar: “El asesinato de Martin Luther King sofocó mi patriotismo”
#
# https://www.lavanguardia.com/deportes/baloncesto/20200623/481924104209/kareem-abdul-jabbar-nba-entrevista-la-vanguardia-baloncesto-lakers.html
# Author: Kareem Abdul-Jabbar (Kevork S. Djansezian / Getty)
# Fecha:
# 		23/06/2020 01:37
# Imagen: https://www.lavanguardia.com/r/GODO/LV/p7/WebSite/2020/06/23/Recortada/img_smauri_20200622-152236_imagenes_lv_getty_gettyimages-1202371564-kZxE-U481924104209YwG-992x558@LaVanguardia-Web.jpg
# ...
#
# Horóscopo diario: ¿cuál es tu predicción para el martes 23 de junio?
#
# https://www.lavanguardia.com/horoscopo/20200622/481910550996/horoscopo-hoy-23-junio-2020.html
# Author: Descubre la suerte que te deparará hoy el horóscopo (La Vanguardia)
# Fecha:
# 		22/06/2020 17:37
# Imagen: https://www.lavanguardia.com/r/GODO/LV/p7/WebSite/2020/06/22/Recortada/img_fcastanyer_20200316-204801_imagenes_lv_otras_fuentes_frame_horoscopo-645-kAPB-U481910550996lD-992x558@LaVanguardia-Web.jpg
# Contenido: ['\nLa Vanguardia te ofrece de primera mano las \npredicciones delHoróscopo\n del martes 23 de junio de todos los signos del zodiaco: Aries, Tauro, Géminis, Cáncer, Leo, Virgo, Libra, Escorpio, Sagitario, Capricornio, Acuario y Piscis. \n\n\n\n\nAries\n\n\n\nProblemas, que vienen ya de lejos, tenderán a remitir hasta muy finales de diciembre. De todos modos, no es que desaparezcan.\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.registerLazyLoad\');\n\t\t \t})\n\t \t\t\n\n\t\t\t\t\t\t\tHoróscopo Diario La Vanguardia Discover\n\t\t\t\t\t\t\t\t\t\t(LV)\n\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n\n\n\n\n\nTauro\n\n\n\nSi tiene entre manos un proyecto de gran importancia, de carácter muy interesante, tomará un ritmo más lento durante unos meses.\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.registerLazyLoad\');\n\t\t \t})\n\t \t\t\n\n\t\t\t\t\t\t\tHoróscopo Diario La Vanguardia Discover\n\t\t\t\t\t\t\t\t\t\t(LV)\n\t\t\t\t\t\t\n\n\n\n\n\n\n\nGéminis\n\n\n\nLa situación de incertidumbre que amenaza su proyección profesional, no se hará tan evidente durante unos meses. Pero atención.\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.registerLazyLoad\');\n\t\t \t})\n\t \t\t\n\n\t\t\t\t\t\t\tHoróscopo Diario La Vanguardia Discover\n\t\t\t\t\t\t\t\t\t\t(LV)\n\t\t\t\t\t\t\n\n\n\n\n\n\n\n\nCáncer\n\n\n\nEs un periodo en que disfruta de gran claridad. Ahora bien, sus buenas propuestas tardarán en dar sus frutos hasta diciembre.\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.registerLazyLoad\');\n\t\t \t})\n\t \t\t\n\n\t\t\t\t\t\t\tHoróscopo Diario La Vanguardia Discover\n\t\t\t\t\t\t\t\t\t\t(LV)\n\t\t\t\t\t\t\n\n\n\n\n\n\n\nLeo\n\n\n\nDebe ser muy cauto en aquellos temas económicos que sean fruto de alguna asociación pues podría surgir algún tipo de fraude.\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.registerLazyLoad\');\n\t\t \t})\n\t \t\t\n\n\t\t\t\t\t\t\tHoróscopo Diario La Vanguardia Discover\n\t\t\t\t\t\t\t\t\t\t(LV)\n\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n\n\n\n\n\nVirgo\n\n\n\nDebe estar muy alerta, pues la tendencia actual a que se vea envuelto en relaciones complicadas tardará tiempo en aclararse.\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.registerLazyLoad\');\n\t\t \t})\n\t \t\t\n\n\t\t\t\t\t\t\tHoróscopo Diario La Vanguardia Discover\n\t\t\t\t\t\t\t\t\t\t(LV)\n\t\t\t\t\t\t\n\n\n\n\n\n\n\nLibra\n\n\n\nPeriodo en el que debe cuidarse y vigilar estrechamente su salud, ya que podría sufrir algún trastorno de difícil diagnóstico.\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.registerLazyLoad\');\n\t\t \t})\n\t \t\t\n\n\t\t\t\t\t\t\tHoróscopo Diario La Vanguardia Discover\n\t\t\t\t\t\t\t\t\t\t(LV)\n\t\t\t\t\t\t\n\n\n\n\n\n\n\nEscorpio\n\n\n\nEs una época propicia al amor, durante la que puede vivir una romántica historia de amor, aunque quizás mantenida en el secreto.\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.registerLazyLoad\');\n\t\t \t})\n\t \t\t\n\n\t\t\t\t\t\t\tHoróscopo Diario La Vanguardia Discover\n\t\t\t\t\t\t\t\t\t\t(LV)\n\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n\n\n\n\n\nSagitario\n\n\n\nTodavía sigue existiendo una situación que podría llegar a resultar problemática para la familia o en cuanto a bienes inmuebles.\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \ ...
#
# Virginia Torrecilla se retira del fútbol para seguir tratamiento médico
#
# https://www.lavanguardia.com/deportes/futbol-femenino/20200622/481910293482/virginia-torrecilla-atletico-de-madrid-tratamiento-tumor-cerebral.html
# Author: La jugadora del Atlético de Madrid, Virginia Torrecilla (Instagram Virginia Torrecilla)
# Fecha:
# 		22/06/2020 17:35
# Imagen: https://www.lavanguardia.com/r/GODO/LV/p7/WebSite/2020/06/22/Recortada/img_pmillan_20200521-213134_imagenes_lv_otras_fuentes_captura_de_pantalla_2020-05-21_a_les_213048-kLMD-U481910293482TVF-992x558@LaVanguardia-Web.png
# Contenido: ['\n\nVirginia Torrecilla ha anunciado que se retira del fútbol durante un tiempo para seguir tratamiento médico después de ser operada de un tumor cerebral. La jugadora del Atlético de Madrid asegura en las redes sociales que estará “varios meses” alejada de los terrenos de juego, pero que seguirá animando desde la distancia al club colchonero y a la selección femenina.\n“Como bien sabéis tendré que someterme a un tratamiento durante varios meses...eso implica apartar el fútbol durante un tiempo. Mientras tanto seré una fan más animando a mi equipo, el Atlético femenino, y a la selección española femenina ¡¡GRACIAS!! “, escribió la jugadora en su cuenta de twitter.\n\n\n\n\n\n\n\n\n \t\r\n\tgg.didomi.doWhenConsent(true, "c:twitterwi-wUmBnnKy", function(){\r\n\t    var fbScript = document.createElement("script");\r\n        fbScript.src = "//platform.twitter.com/widgets.js";\r\n        fbScript.async = true;\r\n        document.querySelector("body").appendChild(fbScript);\r\n    } );\t\r\n\r\n    \nLa centrocampista mallorquina, de 25 años, fue operada con éxito hace justo un mes en la Clínica Universidad de Navarra de Pamplona. “Gané el partido más importante de mi vida, gracias a vosotros! Y que sepáis que esto es el principio de algo grande, por que me ha gustado ganar”, escribió tras la intervención junto a una foto suya con la cabeza vendada.\nTras dar a conocer su problema de salud, los mensajes de apoyo hacia Torrecilla se multiplicaron en las redes sociales y también en el campo. Su compañero de club Diego Costa le dedicó su gol en San Mamés ante el Athletic, cuando el delantero celebró el tanto con una camiseta con el nombre y el dorsal de la jugadora.\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.registerLazyLoad\');\n\t\t \t})\n\t \t\t\n\n\t\t\t\t\t\t\tLa centrocampista del Atlético de Madrid Virginia Torrecilla\n\t\t\t\t\t\t\t\t\t\t(Otras Fuentes)\n\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n\n\nTorrecilla empezó su carrera en la élite del fútbol femenino defendiendo los colores del Barça durante tres temporadas, de 2012 a 2015, y posteriormente se fue a la liga francesa para enfundarse la camiseta del Montpellier durante cuatro temporadas. El verano pasado fichó por el Atlético de Madrid, que este año ha quedado segundo de la Liga Iberdrola tras la cancelación del curso por el coronavirus. Además ha sido internacional con España en 83 ocasiones desde que debutara con la absoluta en 2013.\n\nConsulta la clasificación de la Liga Iberdrola.\n\n\n\n\n\n\n']
#
# [EN DIRECTO]: Sigue la presentación del Apple WWDC 2020
#
# https://www.lavanguardia.com/tecnologia/20200622/481908438683/presentacion-evento-apple-wwdc-2020-apple-park-online-novedades-video-seo-ext.html
# Manresa hará un gran pacto de ciudad para evitar la segregación escolar en los centros
#
# https://www.lavanguardia.com/local/catalunya/20200622/481905980373/manresa-segregacion-escolar-centros-pacto-ciudad.html
#
# Conoce la última hora sobre el coronavirus en España
#
# https://www.lavanguardia.com/vida/20200622/481909975817/ultima-hora-coronavirus-espana-fernando-simon-fallecidos-contagiados-video-seo-ext.html
# Author: Sin autor
# Fecha:
# 		22/06/2020 17:11
# Imagen: Imagen no disponible
# Contenido: ['\nEsta tarde de lunes 22 de junio el director del Centro de Coordinación de Alertas y Emergencias Sanitarias del Ministerio de Sanidad, Fernando Simón, realizará una nueva rueda de prensa. El especialista analizará el número de casos contagiados y fallecidos que han tenido lugar en España. \n\n\nEspaña estrenó ayer la llamada “nueva normalidad”\n\n\nSegún datos de la OMS, este pasado domingo se registraron 183.020 nuevos positivos, de los cuales 116.041 han sido en el continente americano. El aumento récord de este domingo sitúa la cifra total de contagios por coronavirus en el mundo en 8.708.008.\n\n\n\n\n\n']
#
# El cuartel de Paterna ha registrado 29 bajas psiquiátricas y un posible suicidio en 2 años
#
# https://www.lavanguardia.com/local/valencia/20200622/481909525320/cuartel-paterna-29-bajas-suicidio-dos-anos-nbq-elkin-segura.html
#
# La estatua de fray Junípero Serra de Palma amanece con la palabra “racista” pintada
#
# https://www.lavanguardia.com/local/baleares/20200622/481909011696/estatua-fray-junipero-serra-pintada-palma-racista.html
# Author: La estatua dedicada en Palma en la Plaza de Sant Francesc a Fray Junípero Serra ha amanecido este lunes con la palabra "racista" pintada en su base (ATIENZA / EFE)
# Fecha:
# 		22/06/2020 17:05
# Imagen: https://www.lavanguardia.com/r/GODO/LV/p7/WebSite/2020/06/22/Recortada/20200622-637284352608397229_20200622151502-k11D-U481909011696Z5H-992x558@LaVanguardia-Web.jpg
# Contenido: ['\nLa estatua de Junípero Serra, situada en la plaza Sant Francesc de Palma, ha aparecido este lunes con pintadas de “racista” después de que la regidora de Justicia Social, Feminismo y Lgtbi+, Sonia Vivas, de Unidas Podemos, abogara por retirar “pacíficamente” la estatua del monje franciscano de la ciudad.\nA través de su cuenta de Twitter, la regidora aseguró también que los habitantes de San Francisco habían tomado la palabra al tirar la estatua de Fray Junípero Serra. “Cuentan una historia política de élites y oligarquías”, dijo.\nFue el sábado por la tarde cuando activistas derribaron la estatua de Fray Junípero Serra, en San Francisco, por ser considerado “asesino de indígenas”. The Hispanic Council condenó el hecho y aseguró que “lejos de ser un genocida o un racista, representó todo lo contrario”.\n\n\n\n\n\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.registerLazyLoad\');\n\t\t \t})\n\t \t\t\n\n\t\t\t\t\t\t\tUn hombre hace una foto a la estatua dedicada en Palma en la Plaza de Sant Francesc a Fray Junípero Serra ha amanecido este lunes con la palabra \'racista\' pintada en su base\n\t\t\t\t\t\t\t\t\t\t(ATIENZA / EFE)\n\t\t\t\t\t\t\n\n\n\n\nDel mismo modo, el Ayuntamiento de Palma ha condenado la pintada vandálica con la que la escultura del franciscano ha amanecido este lunes, un rechazo al que Vivas, en declaraciones a Europa Press, se ha sumado: “Una pintada no soluciona nada, lo único que genera es repulsa”.\nVivas ha subrayado que los actos vandálicos “no son la vía”. “Se debería poner sobre la mesa a través de asociaciones las necesidades que existen de resignificar la ciudad y no tener estatuas de algo como la colonización de América”, ha afirmado.\nDe hecho, la regidora de Cort ha admitido que la colonización “es algo cercano que sigue impactando en la sociedad”. Por este motivo, ha apostado por que “la gente joven sepa cuál es la historia real”, que para Vivas no es la “que está narrada desde el punto de vista de las élites y la oligarquías”. \n\n\nCs critica a Hila por ser “cómplice de la bajeza de Podemos”\n\n\nAnte esto, Ciudadanos en el Ayuntamiento de Palma ha condenado las pintadas y ha lamentado la actitud de Vivas por “alentar a este ataque”. Además, Cs ha criticado al alcalde de Palma, el socialista José Hila, por ser “cómplice de la bajeza institucional a la que Podemos somete a Cort”.\n\n\n\n\n\nDel mismo modos, los grupos políticos parlamentarios, durante la rueda de prensa de repaso sobre la actualidad política, han rechazado este acto vandálico. Así, el portavoz de MÉS per Mallorca en la Cámara balear, Miquel Ensenyat, ha asegurado que la Historia “no se puede juzgar desde otro momento histórico”.\nPor su parte, el grupo parlamentario Ciudadanos, a través de su portavoz, Marc Pérez-Ribas, ha anunciado que han presentado en el Congreso de los Diputados una Proposición No de Ley para defender “el legado español” en América y, de este modo, los ciudadanos tengan “conocimiento de los grandes ilustres”.\n\n\n\n\n\t\t \twindow.addEventListener("DOMContentLoaded", function(event){\n\t\t \t   gg.registry.register(\'lazyload-story-images\', \'gg.registerLazyLoad\');\n\t\t \t})\n\t \t\t\n\n\t\t\t\t\t\t\tLa estatua dedicada en Palma en la Plaza de Sant Francesc a Fray Junípero Serra ha amanecido este lunes con la palabra \'racista\' pintada en su base\n\t\t\t\t\t\t\t\t\t\t(ATIENZA / EFE)\n\t\t\t\t\t\t\n\n\n\n\nVox, en cambio, se ha dirigido a la regidora Sonia Vivas y la ha responsabilizado del ataque vandálico a la estatua. “Uno ya no sabe si las manifestaciones de Sonia Vivas, que debería dejar de ser concejal, son por analfabetismo sectario sin precedentes o si es para destrozar el legado de Baleares en el mundo”, ha dicho el portavoz del partido, Jorge Campos.\n\n\n\n\n\nCabe recordar que Vox ha registrado este lunes una propuesta de declaración institucional en el Parlament balear en reconocimient ...
#
# [EN DIRECTO]: ‘Concierto del bioceno’ para las plantas en el Liceu
#
# https://www.lavanguardia.com/cultura/20200622/481909601377/concierto-del-bioceno-liceu-barcelona-plantas-uceli-quartet-crisantemi-de-puccini-video-seo-ext.html
